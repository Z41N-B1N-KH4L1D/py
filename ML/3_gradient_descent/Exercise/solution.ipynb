# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import math

# %%
df = pd.read_csv("test_scores.csv")
y = np.array(df['cs'])
x = np.array(df['math'])

print(x, y)
# Out:
# [92 56 88 70 80 49 65 35 66 67] [98 68 81 80 83 52 66 30 68 73]

# %%
#defining the gradient descent function
def gradient_descent(x, y):
    m = 0.0
    b = 0.0
    learning_rate = 0.0002
    steps = 1000000
    n = len(x)
    cost_previous = float('inf')

    for i in range(steps):
        y_predicted = m * x + b

        md = -(2 / n) * np.sum(x * (y - y_predicted))
        bd = -(2 / n) * np.sum(y - y_predicted)

        m -= learning_rate * md
        b -= learning_rate * bd

        # now compute cost AFTER the update
        y_predicted = m * x + b
        cost = (1 / n) * np.sum((y - y_predicted) ** 2)

        if math.isclose(cost, cost_previous, rel_tol=1e-20):
            break

        cost_previous = cost

    return m, b

# %%
m, b = gradient_descent(x,y)
print(m, b)
# Out:
# 1.0177383552197374 1.9150692591510463

# %%
#Predicting using sklearn library
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(df[['math']], df['cs'])
print(reg.coef_, reg.intercept_)
# Out:
# [1.01773624] 1.9152193111568891
